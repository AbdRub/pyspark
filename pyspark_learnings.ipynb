# %% [markdown]
# # Pyspark Tutorials

# %%
# sc.stop()
from pyspark.sql.types import *
from pyspark.sql.functions import *
import pandas as pd
from pyspark.sql.window import Window
from pyspark.context import SparkContext
from pyspark.sql import SparkSession

sc = SparkContext.getOrCreate()
spark = SparkSession(sc)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


df = spark.read.format('csv').option('header', True).option('inferSchema', 'true').load('BigMartSales.csv')

df = df.withColumn('Current_Date', current_date())

df.toPandas().head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type1          3735.1380   2025-08-16
# 1  Supermarket Type2           443.4228   2025-08-16
# 2  Supermarket Type1          2097.2700   2025-08-16
# 3      Grocery Store           732.3800   2025-08-16
# 4  Supermarket Type1           994.7052   2025-08-16

# %%
my_struct_schema = StructType([
    StructField("Item_Identifier", StringType(), True),
    StructField("Item_Weight", DoubleType(), True),
    StructField("Item_Fat_Content", StringType(), True),
    StructField("Item_Visibility", DoubleType(), True),
    StructField("Item_Type", StringType(), True),
    StructField("Item_MRP", DoubleType(), True),
    StructField("Outlet_Identifier", StringType(), True),
    StructField("Outlet_Establishment_Year", IntegerType(), True),
    StructField("Outlet_Size", StringType(), True),
    StructField("Outlet_Location_Type", StringType(), True),
    StructField("Outlet_Type", StringType(), True),
    StructField("Item_Outlet_Sales", DoubleType(), True)
])

# %%
df.select(
    'item_identifier',
    'item_weight', 
    'item_fat_content',
).toPandas().head(5)
# Out:
#   item_identifier  item_weight item_fat_content
# 0           FDA15         9.30          Low Fat
# 1           DRC01         5.92          Regular
# 2           FDN15        17.50          Low Fat
# 3           FDX07        19.20          Regular
# 4           NCD19         8.93          Low Fat
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.select(
    col('item_identifier'),
    col('item_weight'),
    col('item_fat_content')).toPandas().head(5)
# Out:
#   item_identifier  item_weight item_fat_content
# 0           FDA15         9.30          Low Fat
# 1           DRC01         5.92          Regular
# 2           FDN15        17.50          Low Fat
# 3           FDX07        19.20          Regular
# 4           NCD19         8.93          Low Fat

# %%
df.select(col('item_identifier').alias('Item ID'),
    col('item_weight').alias('Weight'),
    col('item_fat_content').alias('Fat Content')).toPandas().head(5)
# Out:
#   Item ID  Weight Fat Content
# 0   FDA15    9.30     Low Fat
# 1   DRC01    5.92     Regular
# 2   FDN15   17.50     Low Fat
# 3   FDX07   19.20     Regular
# 4   NCD19    8.93     Low Fat

# %%
df.filter(col('item_fat_content') == 'Regular').toPandas().head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           DRC01        5.920          Regular         0.019278
# 1           FDX07       19.200          Regular         0.000000
# 2           FDP36       10.395          Regular         0.000000
# 3           FDO10       13.650          Regular         0.012741
# 4           FDH17       16.200          Regular         0.016687
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Soft Drinks   48.2692            OUT018
# 1  Fruits and Vegetables  182.0950            OUT010
# 2           Baking Goods   51.4008            OUT018
# 3            Snack Foods   57.6588            OUT013
# 4           Frozen Foods   96.9726            OUT045
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       2009      Medium               Tier 3
# 1                       1998        None               Tier 3
# 2                       2009      Medium               Tier 3
# 3                       1987        High               Tier 3
# 4                       2002        None               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type2           443.4228   2025-08-16
# 1      Grocery Store           732.3800   2025-08-16
# 2  Supermarket Type2           556.6088   2025-08-16
# 3  Supermarket Type1           343.5528   2025-08-16
# 4  Supermarket Type1          1076.5986   2025-08-16

# %%
df.filter((col('item_type')=='Soft Drinks') & (col('item_weight')<10)).toPandas().head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           DRC01         5.92          Regular         0.019278  Soft Drinks
# 1           DRZ11         8.85          Regular         0.113124  Soft Drinks
# 2           DRF49         7.27          Low Fat         0.071078  Soft Drinks
# 3           DRK12         9.50               LF         0.041878  Soft Drinks
# 4           DRK01         7.63          Low Fat         0.061053  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0   48.2692            OUT018                       2009      Medium
# 1  122.5388            OUT018                       2009      Medium
# 2  114.2518            OUT046                       1997       Small
# 3   32.9900            OUT035                       2004       Small
# 4   95.4436            OUT035                       2004       Small
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Current_Date
# 0               Tier 3  Supermarket Type2           443.4228   2025-08-16
# 1               Tier 3  Supermarket Type2          1609.9044   2025-08-16
# 2               Tier 1  Supermarket Type1          2618.5914   2025-08-16
# 3               Tier 2  Supermarket Type1           133.1600   2025-08-16
# 4               Tier 2  Supermarket Type1          1418.1540   2025-08-16

# %%
df.filter((col('Outlet_size').isNull() & (col('Outlet_location_type').isin('Tier 1', 'Tier 2')))).toPandas().head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDH17        16.20          Regular         0.016687
# 1           FDU28        19.20          Regular         0.094450
# 2           NCD06        13.00          Low Fat         0.099887
# 3           FDO23        17.85          Low Fat         0.000000
# 4           NCP05        19.60          Low Fat         0.000000
#
#             Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0        Frozen Foods   96.9726            OUT045                       2002
# 1        Frozen Foods  187.8214            OUT017                       2007
# 2           Household   45.9060            OUT017                       2007
# 3              Breads   93.1436            OUT045                       2002
# 4  Health and Hygiene  153.3024            OUT045                       2002
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0        None               Tier 2  Supermarket Type1          1076.5986
# 1        None               Tier 2  Supermarket Type1          4710.5350
# 2        None               Tier 2  Supermarket Type1           838.9080
# 3        None               Tier 2  Supermarket Type1          2174.5028
# 4        None               Tier 2  Supermarket Type1          2428.8384
#
#   Current_Date
# 0   2025-08-16
# 1   2025-08-16
# 2   2025-08-16
# 3   2025-08-16
# 4   2025-08-16

# %%
df.withColumnRenamed('item_identifier', 'ItemID') \
    .withColumnRenamed('item_weight', 'Weight') \
    .withColumnRenamed('item_fat_content', 'FatContent') \
    .toPandas().head(5)
# Out:
#   ItemID  Weight FatContent  Item_Visibility              Item_Type  Item_MRP  \
# 0  FDA15    9.30    Low Fat         0.016047                  Dairy  249.8092
# 1  DRC01    5.92    Regular         0.019278            Soft Drinks   48.2692
# 2  FDN15   17.50    Low Fat         0.016760                   Meat  141.6180
# 3  FDX07   19.20    Regular         0.000000  Fruits and Vegetables  182.0950
# 4  NCD19    8.93    Low Fat         0.000000              Household   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
# 1            OUT018                       2009      Medium
# 2            OUT049                       1999      Medium
# 3            OUT010                       1998        None
# 4            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Current_Date
# 0               Tier 1  Supermarket Type1          3735.1380   2025-08-16
# 1               Tier 3  Supermarket Type2           443.4228   2025-08-16
# 2               Tier 1  Supermarket Type1          2097.2700   2025-08-16
# 3               Tier 3      Grocery Store           732.3800   2025-08-16
# 4               Tier 3  Supermarket Type1           994.7052   2025-08-16

# %%
df.withColumn('flag', lit('new')).toPandas().head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date flag
# 0  Supermarket Type1          3735.1380   2025-08-16  new
# 1  Supermarket Type2           443.4228   2025-08-16  new
# 2  Supermarket Type1          2097.2700   2025-08-16  new
# 3      Grocery Store           732.3800   2025-08-16  new
# 4  Supermarket Type1           994.7052   2025-08-16  new

# %%
df.withColumn('Product', col('item_weight') * col('item_MRP')).toPandas().head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date      Product
# 0  Supermarket Type1          3735.1380   2025-08-16  2323.225560
# 1  Supermarket Type2           443.4228   2025-08-16   285.753664
# 2  Supermarket Type1          2097.2700   2025-08-16  2478.315000
# 3      Grocery Store           732.3800   2025-08-16  3496.224000
# 4  Supermarket Type1           994.7052   2025-08-16   480.982302

# %%
df.withColumn('Item_Fat_Content', regexp_replace(col('item_fat_content'), 'Regular', 'Reg')) \
    .withColumn('Item_Fat_Content', regexp_replace(col('Item_Fat_Content'), 'Low Fat', 'LF')).toPandas().head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30               LF         0.016047
# 1           DRC01         5.92              Reg         0.019278
# 2           FDN15        17.50               LF         0.016760
# 3           FDX07        19.20              Reg         0.000000
# 4           NCD19         8.93               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type1          3735.1380   2025-08-16
# 1  Supermarket Type2           443.4228   2025-08-16
# 2  Supermarket Type1          2097.2700   2025-08-16
# 3      Grocery Store           732.3800   2025-08-16
# 4  Supermarket Type1           994.7052   2025-08-16

# %%
# df.withColumn('Item_weight', col('item_weight').cast(StringType()))

# %%
df.printSchema()
# Out:
# root
#  |-- Item_Identifier: string (nullable = true)
#  |-- Item_Weight: double (nullable = true)
#  |-- Item_Fat_Content: string (nullable = true)
#  |-- Item_Visibility: double (nullable = true)
#  |-- Item_Type: string (nullable = true)
#  |-- Item_MRP: double (nullable = true)
#  |-- Outlet_Identifier: string (nullable = true)
#  |-- Outlet_Establishment_Year: integer (nullable = true)
#  |-- Outlet_Size: string (nullable = true)
#  |-- Outlet_Location_Type: string (nullable = true)
#  |-- Outlet_Type: string (nullable = true)
#  |-- Item_Outlet_Sales: double (nullable = true)
#  |-- Current_Date: date (nullable = false)

# %%
df.sort(col('Item_type').desc()).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDH35        18.25          Low Fat         0.000000
# 1           FDH35          NaN          Low Fat         0.059957
# 2           FDB11        16.00          Low Fat         0.060837
# 3           FDB35        12.30          Regular         0.064750
# 4           FDB35        12.30          Regular         0.064565
#
#        Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Starchy Foods  164.7526            OUT045                       2002
# 1  Starchy Foods  165.4526            OUT027                       1985
# 2  Starchy Foods  226.8404            OUT035                       2004
# 3  Starchy Foods   92.6804            OUT045                       2002
# 4  Starchy Foods   92.9804            OUT013                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0        None               Tier 2  Supermarket Type1          4604.6728
# 1      Medium               Tier 3  Supermarket Type3          5262.4832
# 2       Small               Tier 2  Supermarket Type1          6301.1312
# 3        None               Tier 2  Supermarket Type1          1010.6844
# 4        High               Tier 3  Supermarket Type1          1929.4884
#
#   Current_Date
# 0   2025-08-16
# 1   2025-08-16
# 2   2025-08-16
# 3   2025-08-16
# 4   2025-08-16

# %%
df.sort(col('Item_Visibility').asc()).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDX07       19.200          Regular              0.0
# 1           NCD19        8.930          Low Fat              0.0
# 2           FDP36       10.395          Regular              0.0
# 3           FDY07       11.800          Low Fat              0.0
# 4           FDP33       18.700          Low Fat              0.0
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0  Fruits and Vegetables  182.0950            OUT010
# 1              Household   53.8614            OUT013
# 2           Baking Goods   51.4008            OUT018
# 3  Fruits and Vegetables   45.5402            OUT049
# 4            Snack Foods  256.6672            OUT018
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1998        None               Tier 3
# 1                       1987        High               Tier 3
# 2                       2009      Medium               Tier 3
# 3                       1999      Medium               Tier 1
# 4                       2009      Medium               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0      Grocery Store           732.3800   2025-08-16
# 1  Supermarket Type1           994.7052   2025-08-16
# 2  Supermarket Type2           556.6088   2025-08-16
# 3  Supermarket Type1          1516.0266   2025-08-16
# 4  Supermarket Type2          3068.0064   2025-08-16

# %%
df.sort(['Item_Weight', 'Item_Visibility'], ascending=[0, 0]).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDR07        21.35          Low Fat         0.130127
# 1           FDC02        21.35          Low Fat         0.115195
# 2           FDR07        21.35          Low Fat         0.078061
# 3           FDC02        21.35          Low Fat         0.069103
# 4           FDC02        21.35          Low Fat         0.068822
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0  Fruits and Vegetables   96.2094            OUT010
# 1                 Canned  258.3278            OUT010
# 2  Fruits and Vegetables   96.0094            OUT018
# 3                 Canned  259.9278            OUT018
# 4                 Canned  258.3278            OUT046
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1998        None               Tier 3
# 1                       1998        None               Tier 3
# 2                       2009      Medium               Tier 3
# 3                       2009      Medium               Tier 3
# 4                       1997       Small               Tier 1
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0      Grocery Store           190.4188   2025-08-16
# 1      Grocery Store           520.6556   2025-08-16
# 2  Supermarket Type2           380.8376   2025-08-16
# 3  Supermarket Type2          6768.5228   2025-08-16
# 4  Supermarket Type1          7028.8506   2025-08-16

# %%
df.sort(['Item_Weight', 'Item_Visibility'], ascending=[0, 1]).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDC02        21.35          Low Fat         0.068765
# 1           FDC02        21.35          Low Fat         0.068809
# 2           FDC02        21.35          Low Fat         0.068822
# 3           FDC02        21.35          Low Fat         0.069103
# 4           FDR07        21.35          Low Fat         0.078061
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                 Canned  260.4278            OUT013
# 1                 Canned  258.5278            OUT035
# 2                 Canned  258.3278            OUT046
# 3                 Canned  259.9278            OUT018
# 4  Fruits and Vegetables   96.0094            OUT018
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1987        High               Tier 3
# 1                       2004       Small               Tier 2
# 2                       1997       Small               Tier 1
# 3                       2009      Medium               Tier 3
# 4                       2009      Medium               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type1          3644.5892   2025-08-16
# 1  Supermarket Type1          5206.5560   2025-08-16
# 2  Supermarket Type1          7028.8506   2025-08-16
# 3  Supermarket Type2          6768.5228   2025-08-16
# 4  Supermarket Type2           380.8376   2025-08-16

# %%
df.limit(5).toPandas()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type1          3735.1380   2025-08-16
# 1  Supermarket Type2           443.4228   2025-08-16
# 2  Supermarket Type1          2097.2700   2025-08-16
# 3      Grocery Store           732.3800   2025-08-16
# 4  Supermarket Type1           994.7052   2025-08-16

# %%
df.drop('Item_Visibility', 'Outlet_Identifier').toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content              Item_Type  \
# 0           FDA15         9.30          Low Fat                  Dairy
# 1           DRC01         5.92          Regular            Soft Drinks
# 2           FDN15        17.50          Low Fat                   Meat
# 3           FDX07        19.20          Regular  Fruits and Vegetables
# 4           NCD19         8.93          Low Fat              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0  249.8092                       1999      Medium               Tier 1
# 1   48.2692                       2009      Medium               Tier 3
# 2  141.6180                       1999      Medium               Tier 1
# 3  182.0950                       1998        None               Tier 3
# 4   53.8614                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type1          3735.1380   2025-08-16
# 1  Supermarket Type2           443.4228   2025-08-16
# 2  Supermarket Type1          2097.2700   2025-08-16
# 3      Grocery Store           732.3800   2025-08-16
# 4  Supermarket Type1           994.7052   2025-08-16

# %%
df.dropDuplicates().toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDN04       11.800              reg         0.014087
# 1           FDG24        7.975          Low Fat         0.014619
# 2           FDV02       16.750          Low Fat         0.060495
# 3           FDC40       16.000          Regular         0.065010
# 4           FDP24       20.600          Low Fat         0.082935
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Frozen Foods  180.3344            OUT046                       1997
# 1  Baking Goods   85.2250            OUT013                       1987
# 2         Dairy  169.8106            OUT013                       1987
# 3         Dairy   79.5986            OUT013                       1987
# 4  Baking Goods  119.5756            OUT013                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0       Small               Tier 1  Supermarket Type1          1427.4752
# 1        High               Tier 3  Supermarket Type1          1081.9250
# 2        High               Tier 3  Supermarket Type1          3251.1014
# 3        High               Tier 3  Supermarket Type1           934.7832
# 4        High               Tier 3  Supermarket Type1          2665.8632
#
#   Current_Date
# 0   2025-08-16
# 1   2025-08-16
# 2   2025-08-16
# 3   2025-08-16
# 4   2025-08-16

# %%
df.drop_duplicates(subset=['Item_Type']).toPandas()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDP36       10.395          Regular         0.000000
# 1            FDO23       17.850          Low Fat         0.000000
# 2            FDP49        9.000          Regular         0.069089
# 3            FDC14          NaN          Regular         0.072222
# 4            FDA15        9.300          Low Fat         0.016047
# 5            FDH17       16.200          Regular         0.016687
# 6            FDX07       19.200          Regular         0.000000
# 7            DRI11          NaN          Low Fat         0.034238
# 8            NCB42       11.800          Low Fat         0.008596
# 9            NCD19        8.930          Low Fat         0.000000
# 10           FDN15       17.500          Low Fat         0.016760
# 11           NCN07       18.500          Low Fat         0.056816
# 12           FDG33          NaN          Regular         0.139561
# 13           FDO10       13.650          Regular         0.012741
# 14           DRC01        5.920          Regular         0.019278
# 15           FDH35       18.250          Low Fat         0.000000
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0            Baking Goods   51.4008            OUT018
# 1                  Breads   93.1436            OUT045
# 2               Breakfast   56.3614            OUT046
# 3                  Canned   43.6454            OUT019
# 4                   Dairy  249.8092            OUT049
# 5            Frozen Foods   96.9726            OUT045
# 6   Fruits and Vegetables  182.0950            OUT010
# 7             Hard Drinks  113.2834            OUT027
# 8      Health and Hygiene  115.3492            OUT018
# 9               Household   53.8614            OUT013
# 10                   Meat  141.6180            OUT049
# 11                 Others  132.1284            OUT010
# 12                Seafood  170.4764            OUT027
# 13            Snack Foods   57.6588            OUT013
# 14            Soft Drinks   48.2692            OUT018
# 15          Starchy Foods  164.7526            OUT045
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                        2009      Medium               Tier 3
# 1                        2002        None               Tier 2
# 2                        1997       Small               Tier 1
# 3                        1985       Small               Tier 1
# 4                        1999      Medium               Tier 1
# 5                        2002        None               Tier 2
# 6                        1998        None               Tier 3
# 7                        1985      Medium               Tier 3
# 8                        2009      Medium               Tier 3
# 9                        1987        High               Tier 3
# 10                       1999      Medium               Tier 1
# 11                       1998        None               Tier 3
# 12                       1985      Medium               Tier 3
# 13                       1987        High               Tier 3
# 14                       2009      Medium               Tier 3
# 15                       2002        None               Tier 2
#
#           Outlet_Type  Item_Outlet_Sales Current_Date
# 0   Supermarket Type2           556.6088   2025-08-16
# 1   Supermarket Type1          2174.5028   2025-08-16
# 2   Supermarket Type1          1547.3192   2025-08-16
# 3       Grocery Store           125.8362   2025-08-16
# 4   Supermarket Type1          3735.1380   2025-08-16
# 5   Supermarket Type1          1076.5986   2025-08-16
# 6       Grocery Store           732.3800   2025-08-16
# 7   Supermarket Type3          2303.6680   2025-08-16
# 8   Supermarket Type2          1621.8888   2025-08-16
# 9   Supermarket Type1           994.7052   2025-08-16
# 10  Supermarket Type1          2097.2700   2025-08-16
# 11      Grocery Store           263.6568   2025-08-16
# 12  Supermarket Type3          3435.5280   2025-08-16
# 13  Supermarket Type1           343.5528   2025-08-16
# 14  Supermarket Type2           443.4228   2025-08-16
# 15  Supermarket Type1          4604.6728   2025-08-16

# %%
df.select(col('Item_Type').alias('Item Type')).drop_duplicates(subset=['Item Type']).toPandas()
# Out:
#                 Item Type
# 0           Starchy Foods
# 1            Baking Goods
# 2                  Breads
# 3   Fruits and Vegetables
# 4                    Meat
# 5             Hard Drinks
# 6             Soft Drinks
# 7               Household
# 8               Breakfast
# 9                   Dairy
# 10            Snack Foods
# 11                 Others
# 12                Seafood
# 13                 Canned
# 14           Frozen Foods
# 15     Health and Hygiene

# %%
df.distinct().toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDN04       11.800              reg         0.014087
# 1           FDG24        7.975          Low Fat         0.014619
# 2           FDV02       16.750          Low Fat         0.060495
# 3           FDC40       16.000          Regular         0.065010
# 4           FDP24       20.600          Low Fat         0.082935
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Frozen Foods  180.3344            OUT046                       1997
# 1  Baking Goods   85.2250            OUT013                       1987
# 2         Dairy  169.8106            OUT013                       1987
# 3         Dairy   79.5986            OUT013                       1987
# 4  Baking Goods  119.5756            OUT013                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0       Small               Tier 1  Supermarket Type1          1427.4752
# 1        High               Tier 3  Supermarket Type1          1081.9250
# 2        High               Tier 3  Supermarket Type1          3251.1014
# 3        High               Tier 3  Supermarket Type1           934.7832
# 4        High               Tier 3  Supermarket Type1          2665.8632
#
#   Current_Date
# 0   2025-08-16
# 1   2025-08-16
# 2   2025-08-16
# 3   2025-08-16
# 4   2025-08-16

# %%
data = [('1', 'Kad'),
        ('2', 'Sid')]
Schema1 = 'id STRING, name STRING'

df1 = spark.createDataFrame(data, schema=Schema1)

# df1.toPandas().head()

data2 = [('Omer', '3'),
         ('Ali', '4')]
Schema2 = 'name STRING, id STRING'

df2 = spark.createDataFrame(data2, schema=Schema2)

df1.unionByName(df2).toPandas().head()
# Out:
#   id  name
# 0  1   Kad
# 1  2   Sid
# 2  3  Omer
# 3  4   Ali

# %%
df.select(initcap('Item_Type')).toPandas().head()
# Out:
#       initcap(Item_Type)
# 0                  Dairy
# 1            Soft Drinks
# 2                   Meat
# 3  Fruits And Vegetables
# 4              Household

# %%
df.select(lower('Item_Type').alias('Item Type')).toPandas().head()
# Out:
#                Item Type
# 0                  dairy
# 1            soft drinks
# 2                   meat
# 3  fruits and vegetables
# 4              household

# %%
df.select(upper('Item_Type').alias('Item Type')).toPandas().head()
# Out:
#                Item Type
# 0                  DAIRY
# 1            SOFT DRINKS
# 2                   MEAT
# 3  FRUITS AND VEGETABLES
# 4              HOUSEHOLD

# %%
df.withColumn('curr_date', current_date()).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date   curr_date
# 0  Supermarket Type1          3735.1380   2025-08-16  2025-08-16
# 1  Supermarket Type2           443.4228   2025-08-16  2025-08-16
# 2  Supermarket Type1          2097.2700   2025-08-16  2025-08-16
# 3      Grocery Store           732.3800   2025-08-16  2025-08-16
# 4  Supermarket Type1           994.7052   2025-08-16  2025-08-16

# %%
df.withColumn('Week_After', date_add('current_date', 7)).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date  Week_After
# 0  Supermarket Type1          3735.1380   2025-08-16  2025-08-23
# 1  Supermarket Type2           443.4228   2025-08-16  2025-08-23
# 2  Supermarket Type1          2097.2700   2025-08-16  2025-08-23
# 3      Grocery Store           732.3800   2025-08-16  2025-08-23
# 4  Supermarket Type1           994.7052   2025-08-16  2025-08-23

# %%
df.withColumn('Week_Before', date_sub('current_date', 7)).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date Week_Before
# 0  Supermarket Type1          3735.1380   2025-08-16  2025-08-09
# 1  Supermarket Type2           443.4228   2025-08-16  2025-08-09
# 2  Supermarket Type1          2097.2700   2025-08-16  2025-08-09
# 3      Grocery Store           732.3800   2025-08-16  2025-08-09
# 4  Supermarket Type1           994.7052   2025-08-16  2025-08-09

# %%
df.withColumn('DateDifference', datediff(dateadd(current_date(), 7), 'current_date')).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date  DateDifference
# 0  Supermarket Type1          3735.1380   2025-08-16               7
# 1  Supermarket Type2           443.4228   2025-08-16               7
# 2  Supermarket Type1          2097.2700   2025-08-16               7
# 3      Grocery Store           732.3800   2025-08-16               7
# 4  Supermarket Type1           994.7052   2025-08-16               7

# %%
df.withColumn('Formatted_Current_Date', date_format('Current_date', 'dd-MM-yyyy')).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date Formatted_Current_Date
# 0  Supermarket Type1          3735.1380   2025-08-16             16-08-2025
# 1  Supermarket Type2           443.4228   2025-08-16             16-08-2025
# 2  Supermarket Type1          2097.2700   2025-08-16             16-08-2025
# 3      Grocery Store           732.3800   2025-08-16             16-08-2025
# 4  Supermarket Type1           994.7052   2025-08-16             16-08-2025

# %%
df.dropna('all').toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type1          3735.1380   2025-08-16
# 1  Supermarket Type2           443.4228   2025-08-16
# 2  Supermarket Type1          2097.2700   2025-08-16
# 3      Grocery Store           732.3800   2025-08-16
# 4  Supermarket Type1           994.7052   2025-08-16

# %%
df.dropna('any').toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           NCD19        8.930          Low Fat         0.000000
# 4           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 3     Household   53.8614            OUT013                       1987
# 4  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
# 3        High               Tier 3  Supermarket Type1           994.7052
# 4      Medium               Tier 3  Supermarket Type2           556.6088
#
#   Current_Date
# 0   2025-08-16
# 1   2025-08-16
# 2   2025-08-16
# 3   2025-08-16
# 4   2025-08-16

# %%
df.dropna(subset=['Outlet_Size']).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           NCD19        8.930          Low Fat         0.000000
# 4           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 3     Household   53.8614            OUT013                       1987
# 4  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
# 3        High               Tier 3  Supermarket Type1           994.7052
# 4      Medium               Tier 3  Supermarket Type2           556.6088
#
#   Current_Date
# 0   2025-08-16
# 1   2025-08-16
# 2   2025-08-16
# 3   2025-08-16
# 4   2025-08-16

# %%
df.fillna('NotAvailable').toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year   Outlet_Size Outlet_Location_Type  \
# 0                       1999        Medium               Tier 1
# 1                       2009        Medium               Tier 3
# 2                       1999        Medium               Tier 1
# 3                       1998  NotAvailable               Tier 3
# 4                       1987          High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type1          3735.1380   2025-08-16
# 1  Supermarket Type2           443.4228   2025-08-16
# 2  Supermarket Type1          2097.2700   2025-08-16
# 3      Grocery Store           732.3800   2025-08-16
# 4  Supermarket Type1           994.7052   2025-08-16

# %%
df.fillna('NotAvailable', subset=['Outlet_Size']).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year   Outlet_Size Outlet_Location_Type  \
# 0                       1999        Medium               Tier 1
# 1                       2009        Medium               Tier 3
# 2                       1999        Medium               Tier 1
# 3                       1998  NotAvailable               Tier 3
# 4                       1987          High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date
# 0  Supermarket Type1          3735.1380   2025-08-16
# 1  Supermarket Type2           443.4228   2025-08-16
# 2  Supermarket Type1          2097.2700   2025-08-16
# 3      Grocery Store           732.3800   2025-08-16
# 4  Supermarket Type1           994.7052   2025-08-16

# %%
df.withColumn('Outlet_Type_Type', split('Outlet_Type', ' ')).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date      Outlet_Type_Type
# 0  Supermarket Type1          3735.1380   2025-08-16  [Supermarket, Type1]
# 1  Supermarket Type2           443.4228   2025-08-16  [Supermarket, Type2]
# 2  Supermarket Type1          2097.2700   2025-08-16  [Supermarket, Type1]
# 3      Grocery Store           732.3800   2025-08-16      [Grocery, Store]
# 4  Supermarket Type1           994.7052   2025-08-16  [Supermarket, Type1]

# %%
df.withColumn('Outlet_Type_Type', split('Outlet_Type', ' ')[1]).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date Outlet_Type_Type
# 0  Supermarket Type1          3735.1380   2025-08-16            Type1
# 1  Supermarket Type2           443.4228   2025-08-16            Type2
# 2  Supermarket Type1          2097.2700   2025-08-16            Type1
# 3      Grocery Store           732.3800   2025-08-16            Store
# 4  Supermarket Type1           994.7052   2025-08-16            Type1

# %%
df.withColumn('Outlet_Type_Type', explode(split('Outlet_Type', ' '))).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           FDA15         9.30          Low Fat         0.016047        Dairy
# 2           DRC01         5.92          Regular         0.019278  Soft Drinks
# 3           DRC01         5.92          Regular         0.019278  Soft Drinks
# 4           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1  249.8092            OUT049                       1999      Medium
# 2   48.2692            OUT018                       2009      Medium
# 3   48.2692            OUT018                       2009      Medium
# 4  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Current_Date  \
# 0               Tier 1  Supermarket Type1          3735.1380   2025-08-16
# 1               Tier 1  Supermarket Type1          3735.1380   2025-08-16
# 2               Tier 3  Supermarket Type2           443.4228   2025-08-16
# 3               Tier 3  Supermarket Type2           443.4228   2025-08-16
# 4               Tier 1  Supermarket Type1          2097.2700   2025-08-16
#
#   Outlet_Type_Type
# 0      Supermarket
# 1            Type1
# 2      Supermarket
# 3            Type2
# 4      Supermarket

# %%
df.withColumn('Type_Flag', array_contains(split('Outlet_Type', ' '), 'Type1' )).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date  Type_Flag
# 0  Supermarket Type1          3735.1380   2025-08-16       True
# 1  Supermarket Type2           443.4228   2025-08-16      False
# 2  Supermarket Type1          2097.2700   2025-08-16       True
# 3      Grocery Store           732.3800   2025-08-16      False
# 4  Supermarket Type1           994.7052   2025-08-16       True

# %%
df.groupBy('Item_Type').agg(sum('Item_MRP')).toPandas().head()
# Out:
#                Item_Type  sum(Item_MRP)
# 0          Starchy Foods     21880.0274
# 1           Baking Goods     81894.7364
# 2                 Breads     35379.1198
# 3  Fruits and Vegetables    178124.0810
# 4                   Meat     59449.8638

# %%
df.sort('Item_Type', ascending=False).groupBy('Item_Type').agg(avg('Item_MRP').alias('AVG_MRP')).toPandas().head()
# Out:
#        Item_Type     AVG_MRP
# 0  Starchy Foods  147.838023
# 1    Soft Drinks  131.492506
# 2    Snack Foods  146.194934
# 3        Seafood  141.841719
# 4         Others  132.851430

# %%
df.groupBy('Item_Type', 'Outlet_Size').agg(sum('Item_MRP').alias('Total_MRP')).toPandas().head()
# Out:
#                Item_Type Outlet_Size   Total_MRP
# 0          Starchy Foods      Medium   7124.1362
# 1  Fruits and Vegetables      Medium  59047.2172
# 2          Starchy Foods        None   6040.6402
# 3                 Breads        None  10011.5004
# 4           Baking Goods        None  23433.8388

# %%
df.groupBy('Item_Type', 'Outlet_Size').agg(sum('Item_MRP').alias('Total_MRP'), avg('Item_MRP').alias('Average_MRP')).toPandas().head()
# Out:
#                Item_Type Outlet_Size   Total_MRP  Average_MRP
# 0          Starchy Foods      Medium   7124.1362   148.419504
# 1  Fruits and Vegetables      Medium  59047.2172   142.971470
# 2          Starchy Foods        None   6040.6402   140.480005
# 3                 Breads        None  10011.5004   139.048617
# 4           Baking Goods        None  23433.8388   126.669399

# %%
# Create a sample DataFrame to demonstrate collect_list
sample_data = [
    ("A", "apple"),
    ("A", "apricot"),
    ("B", "banana"),
    ("B", "blueberry"),
    ("C", "cherry")
]
sample_schema = ["Category", "Fruit"]

sample_df = spark.createDataFrame(sample_data, sample_schema)

# Group by 'Category' and collect all 'Fruit' values as a list for each group
sample_df.groupBy('Category').agg(collect_list('Fruit').alias('Fruits')).toPandas()
# Out:
#   Category               Fruits
# 0        B  [banana, blueberry]
# 1        C             [cherry]
# 2        A     [apple, apricot]

# %%
df.groupby('Item_Type').pivot('Outlet_Size').agg(avg('Item_MRP')).toPandas().head()
# Out:
#                Item_Type        null        High      Medium       Small
# 0          Starchy Foods  140.480005  158.157074  148.419504  150.270174
# 1                 Breads  139.048617  133.758960  140.861039  145.523651
# 2           Baking Goods  126.669399  129.202044  126.178568  125.213364
# 3  Fruits and Vegetables  142.575160  145.572870  142.971470  148.313370
# 4                   Meat  139.294534  137.244790  136.419132  145.699250

# %%
df.withColumn('VEG/NONVEG_FLAG', when(col('Item_Type')=='MEAT', 'NONVEG').otherwise('VEG')).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date VEG/NONVEG_FLAG
# 0  Supermarket Type1          3735.1380   2025-08-16             VEG
# 1  Supermarket Type2           443.4228   2025-08-16             VEG
# 2  Supermarket Type1          2097.2700   2025-08-16             VEG
# 3      Grocery Store           732.3800   2025-08-16             VEG
# 4  Supermarket Type1           994.7052   2025-08-16             VEG

# %%
df.withColumn('VEG/NONVEG_FLAG',when(col('Item_Type') == 'MEAT', 'NONVEG').otherwise('VEG'))\
        .withColumn('EXP/INEXP_FLAG',when((col('VEG/NONVEG_FLAG') == 'NONVEG') & (col('Item_MRP') > 100), 'NONVEG_EXPENSIVE')
        .when((col('VEG/NONVEG_FLAG') == 'NONVEG') & (col('Item_MRP') <= 100), 'NONVEG_INEXPENSIVE')
        .when((col('VEG/NONVEG_FLAG') == 'VEG') & (col('Item_MRP') > 100), 'VEG_EXPENSIVE')
        .when((col('VEG/NONVEG_FLAG') == 'VEG') & (col('Item_MRP') <= 100), 'VEG_INEXPENSIVE')
        .otherwise('UNKNOWN')).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998        None               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales Current_Date VEG/NONVEG_FLAG  \
# 0  Supermarket Type1          3735.1380   2025-08-16             VEG
# 1  Supermarket Type2           443.4228   2025-08-16             VEG
# 2  Supermarket Type1          2097.2700   2025-08-16             VEG
# 3      Grocery Store           732.3800   2025-08-16             VEG
# 4  Supermarket Type1           994.7052   2025-08-16             VEG
#
#     EXP/INEXP_FLAG
# 0    VEG_EXPENSIVE
# 1  VEG_INEXPENSIVE
# 2    VEG_EXPENSIVE
# 3    VEG_EXPENSIVE
# 4  VEG_INEXPENSIVE

# %%
# Create a Spark session
# spark = SparkSession.builder.appName("InnerJoinExample").getOrCreate()

# Create two sample DataFrames
data1 = [("Alice", 1), ("Bob", 2), ("Cathy", 3)]
data2 = [("Alice", "F"), ("Bob", "M"), ("David", "M")]

df1 = spark.createDataFrame(data1, ["Name", "ID"])
df2 = spark.createDataFrame(data2, ["Name", "Gender"])

# Perform an inner join on the two DataFrames
# joined_df = df1.join(df2, on="Name", how="inner")
df1.join(df2, df1["Name"] == df2["Name"], "inner").toPandas().head()


# Show the result
# joined_df.show()
# Out:
#     Name  ID   Name Gender
# 0  Alice   1  Alice      F
# 1    Bob   2    Bob      M

# %%
df1.join(df2, df1['Name']==df2['Name'], 'left').toPandas().head()\
# Out:
#     Name  ID   Name Gender
# 0    Bob   2    Bob      M
# 1  Alice   1  Alice      F
# 2  Cathy   3   None   None

# %%
df1.join(df2, df1['Name']==df2['Name'], 'right').toPandas().head()
# Out:
#     Name   ID   Name Gender
# 0    Bob  2.0    Bob      M
# 1  Alice  1.0  Alice      F
# 2   None  NaN  David      M

# %%
df1.join(df2, df1['Name']==df2['Name'], 'anti').toPandas().head()
# Out:
#     Name  ID
# 0  Cathy   3

# %%
df.withColumn('RowNum', row_number().over(Window.orderBy('Item_Identifier'))).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           DRA12         11.6          Low Fat         0.041178  Soft Drinks
# 1           DRA12         11.6          Low Fat         0.000000  Soft Drinks
# 2           DRA12         11.6          Low Fat         0.040912  Soft Drinks
# 3           DRA12         11.6               LF         0.000000  Soft Drinks
# 4           DRA12         11.6          Low Fat         0.041113  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  140.3154            OUT017                       2007        None
# 1  141.6154            OUT045                       2002        None
# 2  142.3154            OUT013                       1987        High
# 3  141.9154            OUT035                       2004       Small
# 4  142.0154            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Current_Date  \
# 0               Tier 2  Supermarket Type1          2552.6772   2025-08-16
# 1               Tier 2  Supermarket Type1          3829.0158   2025-08-16
# 2               Tier 3  Supermarket Type1          2552.6772   2025-08-16
# 3               Tier 2  Supermarket Type1           992.7078   2025-08-16
# 4               Tier 3  Supermarket Type2           850.8924   2025-08-16
#
#    RowNum
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5

# %%
df.withColumn('Rnk', rank().over(Window.orderBy('Item_Identifier'))).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           DRA12         11.6          Low Fat         0.041178  Soft Drinks
# 1           DRA12         11.6          Low Fat         0.000000  Soft Drinks
# 2           DRA12         11.6          Low Fat         0.040912  Soft Drinks
# 3           DRA12         11.6               LF         0.000000  Soft Drinks
# 4           DRA12         11.6          Low Fat         0.041113  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  140.3154            OUT017                       2007        None
# 1  141.6154            OUT045                       2002        None
# 2  142.3154            OUT013                       1987        High
# 3  141.9154            OUT035                       2004       Small
# 4  142.0154            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Current_Date  Rnk
# 0               Tier 2  Supermarket Type1          2552.6772   2025-08-16    1
# 1               Tier 2  Supermarket Type1          3829.0158   2025-08-16    1
# 2               Tier 3  Supermarket Type1          2552.6772   2025-08-16    1
# 3               Tier 2  Supermarket Type1           992.7078   2025-08-16    1
# 4               Tier 3  Supermarket Type2           850.8924   2025-08-16    1

# %%
df.withColumn('Rnk', rank().over(Window.orderBy(col('Item_Identifier').desc())))\
   .withColumn('DenseRnk', dense_rank().over(Window.orderBy(col('Item_Identifier').desc()))).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           NCZ54        14.65          Low Fat         0.000000  Household
# 1           NCZ54          NaN          Low Fat         0.082956  Household
# 2           NCZ54        14.65          Low Fat         0.083528  Household
# 3           NCZ54        14.65          Low Fat         0.083359  Household
# 4           NCZ54          NaN          Low Fat         0.145952  Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  161.5552            OUT010                       1998        None
# 1  164.0552            OUT027                       1985      Medium
# 2  162.4552            OUT045                       2002        None
# 3  161.9552            OUT046                       1997       Small
# 4  160.9552            OUT019                       1985       Small
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales Current_Date  \
# 0               Tier 3      Grocery Store           324.9104   2025-08-16
# 1               Tier 3  Supermarket Type3          5523.4768   2025-08-16
# 2               Tier 2  Supermarket Type1          2274.3728   2025-08-16
# 3               Tier 1  Supermarket Type1          4711.2008   2025-08-16
# 4               Tier 1      Grocery Store           162.4552   2025-08-16
#
#    Rnk  DenseRnk
# 0    1         1
# 1    1         1
# 2    1         1
# 3    1         1
# 4    1         1

# %%
df.withColumn('CumliSum', sum('Item_MRP').over(Window.orderBy('Item_Type'))).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDP36       10.395          Regular         0.000000
# 1           FDW12          NaN          Regular         0.035400
# 2           FDC37          NaN          Low Fat         0.057557
# 3           FDL12       15.850          Regular         0.121633
# 4           FDL12       15.850          Regular         0.121532
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   51.4008            OUT018                       2009
# 1  Baking Goods  144.5444            OUT027                       1985
# 2  Baking Goods  107.6938            OUT019                       1985
# 3  Baking Goods   60.6220            OUT046                       1997
# 4  Baking Goods   59.2220            OUT013                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0      Medium               Tier 3  Supermarket Type2           556.6088
# 1      Medium               Tier 3  Supermarket Type3          4064.0432
# 2       Small               Tier 1      Grocery Store           214.3876
# 3       Small               Tier 1  Supermarket Type1          2576.6460
# 4        High               Tier 3  Supermarket Type1           599.2200
#
#   Current_Date    CumliSum
# 0   2025-08-16  81894.7364
# 1   2025-08-16  81894.7364
# 2   2025-08-16  81894.7364
# 3   2025-08-16  81894.7364
# 4   2025-08-16  81894.7364

# %%
df.withColumn('CumliSum', sum('Item_MRP').over(Window.orderBy('Item_Type').rowsBetween(Window.unboundedPreceding, Window.currentRow))).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDP36       10.395          Regular         0.000000
# 1           FDW12          NaN          Regular         0.035400
# 2           FDC37          NaN          Low Fat         0.057557
# 3           FDL12       15.850          Regular         0.121633
# 4           FDL12       15.850          Regular         0.121532
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   51.4008            OUT018                       2009
# 1  Baking Goods  144.5444            OUT027                       1985
# 2  Baking Goods  107.6938            OUT019                       1985
# 3  Baking Goods   60.6220            OUT046                       1997
# 4  Baking Goods   59.2220            OUT013                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0      Medium               Tier 3  Supermarket Type2           556.6088
# 1      Medium               Tier 3  Supermarket Type3          4064.0432
# 2       Small               Tier 1      Grocery Store           214.3876
# 3       Small               Tier 1  Supermarket Type1          2576.6460
# 4        High               Tier 3  Supermarket Type1           599.2200
#
#   Current_Date  CumliSum
# 0   2025-08-16   51.4008
# 1   2025-08-16  195.9452
# 2   2025-08-16  303.6390
# 3   2025-08-16  364.2610
# 4   2025-08-16  423.4830

# %%
df.withColumn('TotalSum', sum('Item_MRP').over(Window.orderBy('Item_Type').rowsBetween(Window.unboundedPreceding, Window.unboundedFollowing))).toPandas().head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDP36       10.395          Regular         0.000000
# 1           FDW12          NaN          Regular         0.035400
# 2           FDC37          NaN          Low Fat         0.057557
# 3           FDL12       15.850          Regular         0.121633
# 4           FDL12       15.850          Regular         0.121532
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods   51.4008            OUT018                       2009
# 1  Baking Goods  144.5444            OUT027                       1985
# 2  Baking Goods  107.6938            OUT019                       1985
# 3  Baking Goods   60.6220            OUT046                       1997
# 4  Baking Goods   59.2220            OUT013                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0      Medium               Tier 3  Supermarket Type2           556.6088
# 1      Medium               Tier 3  Supermarket Type3          4064.0432
# 2       Small               Tier 1      Grocery Store           214.3876
# 3       Small               Tier 1  Supermarket Type1          2576.6460
# 4        High               Tier 3  Supermarket Type1           599.2200
#
#   Current_Date      TotalSum
# 0   2025-08-16  1.201681e+06
# 1   2025-08-16  1.201681e+06
# 2   2025-08-16  1.201681e+06
# 3   2025-08-16  1.201681e+06
# 4   2025-08-16  1.201681e+06

# %%
df.createTempView('df_view')

# %%
spark.sql("SELECT count(*) FROM df_view where Item_Type = 'Dairy' LIMIT 5").show()
# spark.sql('DROP VIEW IF EXISTS df_view')
# Out:
# +--------+
# |count(1)|
# +--------+
# |     682|
# +--------+

# %%
spark.sql('select distinct Item_Type from df_view').toPandas()
# Out:
#                 Item_Type
# 0           Starchy Foods
# 1            Baking Goods
# 2                  Breads
# 3   Fruits and Vegetables
# 4                    Meat
# 5             Hard Drinks
# 6             Soft Drinks
# 7               Household
# 8               Breakfast
# 9                   Dairy
# 10            Snack Foods
# 11                 Others
# 12                Seafood
# 13                 Canned
# 14           Frozen Foods
# 15     Health and Hygiene
